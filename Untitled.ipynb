# %% [markdown]
# # 0. Setup

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as scipy
import statsmodels.formula.api as smf
import random

from scipy.stats import iqr
from scipy.stats import pearsonr

# %%
df_salary = pd.read_csv('salary .csv')
df_salary
# Out:
#       salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0    53000.0        0            0          0    1.17       1          0
# 1    58000.0        1            0          0    1.24       1          0
# 2    45500.0        0            0          0    1.21       1          0
# 3    35782.0        0            2          1    0.99       1          0
# 4    34731.0        0            2          2    0.91       1          0
# ..       ...      ...          ...        ...     ...     ...        ...
# 509  45906.0        6           17         11    0.92       1          0
# 510  60402.0        6           19          7    0.86       1          0
# 511  53187.0       19            7          6    0.78       1          0
# 512  56542.0        8           20         10    0.78       1          0
# 513  52662.0       13           25         11    0.78       1          0
#
#      position  male  Field  yearsabs
# 0           1     1      3         0
# ...

# %%
#Rename as per metadata
df_salary =df_salary.rename(columns ={'male':'gender', 'experior':'Experience', 'yearsabs':'years_absent'})
df_salary.gender = ['male' if i == 1 else 'female' for i in df_salary.gender]
df_salary.position = ['Jnr_employee' if i == 1 else 'Manager' if  i == 2 else 'Executive' for i in df_salary.position]
df_salary.Field = ['Engineering' if i == 1 else 'Finance' if i == 2 else 'Human Resource' for i in df_salary.Field]
df_salary.shape
# Out:
# (514, 11)

# %%
#$observing null values
null_values= df_salary.isnull().sum()
null_values
# Out:
# salary          1
# exprior         0
# yearsworked     0
# yearsrank       0
# market          0
# degree          0
# otherqual       0
# position        0
# gender          0
# Field           0
# years_absent    0
# dtype: int64

# %%
df_salary.head()
# Out:
#     salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0  53000.0        0            0          0    1.17       1          0
# 1  58000.0        1            0          0    1.24       1          0
# 2  45500.0        0            0          0    1.21       1          0
# 3  35782.0        0            2          1    0.99       1          0
# 4  34731.0        0            2          2    0.91       1          0
#
#        position gender           Field  years_absent
# 0  Jnr_employee   male  Human Resource             0
# 1  Jnr_employee   male         Finance             0
# 2  Jnr_employee   male  Human Resource             2
# 3  Jnr_employee   male  Human Resource             1
# 4  Jnr_employee   male  Human Resource             1

# %% [markdown]
# <p>Above is the sheet of salaries earned by different employees in a company, the years worked, the years spent on the current rank, gender, qualifications and the positions that these employees posess.
#
# There are 514 entries/observation in this dataset meaning that 514 empployees' data is recorded.There is one null value in Salary column</p>

# %%
df_salary.describe()
# Out:
#              salary     exprior  yearsworked   yearsrank      market  \
# count    513.000000  514.000000   514.000000  514.000000  514.000000
# mean   50863.220098    2.926070    12.852140    7.052529    0.948521
# std    12685.132358    4.791397     9.444695    6.414771    0.149380
# min    29000.000000    0.000000     0.000000    0.000000    0.710000
# 25%    40000.000000    0.000000     4.000000    2.000000    0.840000
# 50%    50096.000000    0.500000    12.000000    5.000000    0.920000
# 75%    60345.000000    4.000000    22.000000   12.000000    1.020000
# max    96156.000000   25.000000    41.000000   28.000000    1.330000
#
#            degree   otherqual  years_absent
# count  514.000000  514.000000    514.000000
# mean     0.964981    0.044747      6.982490
# std      0.184008    0.206950     16.873156
# min      0.000000    0.000000      0.000000
# 25%      1.000000    0.000000      0.000000
# 50%      1.000000    0.000000      1.000000
# ...

# %% [markdown]
# Above is a summary statistics showing the statistics for every column in the data frame.

# %%
#Splitting the data into the train and test set
df_sample = df_salary.loc[:,['salary','yearsworked']]
df_sample.head()
# Out:
#     salary  yearsworked
# 0  53000.0            0
# 1  58000.0            0
# 2  45500.0            0
# 3  35782.0            2
# 4  34731.0            2

# %%
#normalise the data using then simple feature scaling
df_sample['salary'] = df_sample['salary']/df_sample['salary'].max()
df_sample.head()
# Out:
#      salary  yearsworked
# 0  0.551188            0
# 1  0.603186            0
# 2  0.473189            0
# 3  0.372124            2
# 4  0.361194            2

# %%
train = np.random.rand(len(df_sample)) < 0.8
df_train = df_sample[train]
df_test = df_sample[~train]
'The length of the train sample is %s'% len(df_train)
# Out:
# 'The length of the train sample is 422'

# %%
'And that of the test sapmple is %s'%len(df_test)
# Out:
# 'And that of the test sapmple is 92'

# %%
sns.set()
sns.regplot(x='yearsworked', y='salary', data=df_salary, scatter_kws={"color": "blue"}, line_kws={"color": "Red"})
plt.show()

# %%
from sklearn.model_selection import train_test_split
df_sample.yearsworked_train,df_sample.yearsworked_test,df_sample.salary_train,df_sample.salary_test=train_test_split(df_sample.yearsworked,df_sample.salary,test_size=0.2)
df_xtrain = df_sample.yearsworked_train 
df_xtest = df_sample.yearsworked_test
df_ytrain = df_sample.salary_train
df_ytest = df_sample.salary_test
df_train = pd.DataFrame([df_xtrain],[df_ytrain])
df_train.head()
# Out:
#           372  80   58   233  508  254  132  47   81   380  ...  479  456  \
# salary                                                      ...
# 0.655945   30    5    3   21   19   23    4    5    3   21  ...   12   12
# 0.585278   30    5    3   21   19   23    4    5    3   21  ...   12   12
# 0.350264   30    5    3   21   19   23    4    5    3   21  ...   12   12
# 0.631443   30    5    3   21   19   23    4    5    3   21  ...   12   12
# 0.544896   30    5    3   21   19   23    4    5    3   21  ...   12   12
#
#           327  339  484  275  170  323  383  266
# salary
# 0.655945   23   26   10   23   23   25   25    1
# 0.585278   23   26   10   23   23   25   25    1
# 0.350264   23   26   10   23   23   25   25    1
# 0.631443   23   26   10   23   23   25   25    1
# 0.544896   23   26   10   23   23   25   25    1
#
# [5 rows x 411 columns]

# %%
sns.set()
fig, axs = plt.subplots(1, 3, sharey=True)
df_salary.plot(kind='scatter', x='yearsworked', y='salary', ax=axs[0], figsize=(20, 10))
df_salary.plot(kind='scatter', x='market', y='salary', ax=axs[1])

df_salary.plot(kind='scatter', x='years_absent', y='salary', ax=axs[2])
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.set()

sns.catplot(x="position", y="salary", jitter=False,data=df_salary)
plt.show()

# %%
sns.catplot(x="Field", y="salary", jitter=False,data=df_salary)
plt.show()

# %%
reg_mod = LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c8d0d6006a51> in <module>
# ----> 1 reg_mod = LinearRegression()
#
# NameError: name 'LinearRegression' is not defined
